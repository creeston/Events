# %%
import json 

def load_json(filename):
    with open(filename, "r", encoding="utf-8") as f:
        return json.load(f)
    
def save_json(filename, obj):
    with open(filename, "w+", encoding="utf-8") as f:
        return json.dump(obj, f, ensure_ascii=False, indent=4) 
    
def load_file(filename):
    return list(open(filename, encoding="utf-8").readlines())


def del_none(d):
    for key, value in list(d.items()):
        if value is None or value == "":
            del d[key]
        elif isinstance(value, dict):
            del_none(value)
    return d

# %%
event_types = load_json("../data/unified.json")["types"]

# %%
tut = load_json("../data/tutby.json")
cd = load_json("../data/citydog.json")
relax = load_json("../data/relax.json")
old_events = load_json("../data/events.json")

events = []
events.extend(tut)
events.extend(cd)
events.extend(relax)
events.extend(old_events)

# %%
tg_vk_events = []
for e in load_file("../labeled_text"):
    labeled_event = json.loads(e)
    delabled_event = {"text": labeled_event["text"], "labels": []}
    for start, end, label in labeled_event["labels"]:
        delabled_event["labels"].append((labeled_event["text"][start:end], label))
    tg_vk_events.append(delabled_event)

# %%
import re
import urlextract
url_extractor = urlextract.URLExtract()
        
freq = [
    "работая с артистами, которых ранее никому не удавалось привезти в Беларусь -",
    "Минские организаторы, не перестают радовать Белорусских фанатов,",
    "Минские организаторы, не перестают радовать фанатов,",
    "Baby Tape, Boulevard Depo, Loqiemean, Jeembo &",
    "Билеты можно приобрести онлайн на AFISHA.TUT.BY",
    "Билеты можно купить онлайн на AFISHA.TUT.BY",
    "Фото и видео",
    "Depo, Loqiemean, Jeembo &",
    "на AFISHA.TUT.BY Фото и видео",
    "О событии"
]

space_re = re.compile(r"[\s|\u2800]+")
comma_re = re.compile(r"(([^\d])\s*,\s*(\w))")
comma_re_2 = re.compile(r"((\w)\s*,\s*([^\d]))")
dash_re = re.compile(r"(([^\d])\s*\-+\s*([^\d]))")
underscore_re = re.compile(r"\_+")
hashtag_re = re.compile(r"#\w+")


def remove_urls(text):
    urls = list(set(url_extractor.find_urls(text)))
    urls.sort(key=lambda u: len(u), reverse=True)
    for url in urls:
        text = text.replace(url, "")
    return text

def preprocess(text):
    text = text.replace("\n", " ")
    text = remove_urls(text)
    text = hashtag_re.sub("", text)
    text = underscore_re.sub(" ", text)
    for f in freq:
        text = text.replace(f, "")
    for whole, first, second in reversed(comma_re.findall(text)):
        text = text.replace(whole, "%s, %s" % (first, second))
    for whole, first, second in reversed(comma_re_2.findall(text)):
        text = text.replace(whole, "%s, %s" % (first, second))
    text = space_re.sub(" ", text)
    return text.strip()

# %%
for e in events:
    text = e['description']
    e['description'] = preprocess(text)

# %%
def detect_lang(text):
    by_letters = ['і', 'ў', 'шч']
    for by_letter in by_letters:
        if by_letter in text:
            return "by"
    return "ru"

def is_suitable_text(text):
    if detect_lang(text) == "by":
        return False
    if len(text) > 2000 or len(text) < 80:
        return False
    if all(not c.isdigit() for c in text):
        return False
    return True

# %%
events = [e for e in events if is_suitable_text(e['description'])]

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
import numpy as np

def remove_duplicated_texts(evs):
    removed_idx = set()
    unique_events = []
    for i, current_text in enumerate(evs):
        if i in removed_idx:
            continue
            
        duplicates = [current_text]
        for j, text in enumerate(evs[i + 1:]):
            if j in removed_idx:
                continue
            res = similar(current_text, text)
            if res > 0.6:
                duplicates.append(text)
                removed_idx.add(j)
                
        unique_event = max(duplicates, key=lambda e: len(e))
        unique_events.append(unique_event)
        
    return unique_events

def remove_duplicated(evs):
    removed_idx = set()
    unique_events = []
    for i, current_event in enumerate(evs):
        if i in removed_idx:
            continue
            
        duplicates = [current_event]
        for j, event in enumerate(evs[i + 1:]):
            if j in removed_idx:
                continue
            res = similar(current_event['description'], event['description'])
            if res > 0.6:
                duplicates.append(event)
                removed_idx.add(j)
                
        unique_event = max(duplicates, key=lambda e: len(e['description']))
        unique_events.append(unique_event)
        
    return unique_events

# %%
import random
import datetime

events_by_dates = {}
for event in events:
    date = event['dates'][0]
    if 'start' in date:
        date = date['start']
    if date:
        if "hour" in date:
            dt = datetime.datetime(year=date['year'], month=date['month'], day=date['day'], hour=date['hour'], minute=date['minute'])
        else:
            dt = datetime.date(year=date['year'], month=date['month'], day=date['day'])
    else:
        dt = datetime.date(year=datetime.MINYEAR, month=1, day=1)

    if dt not in events_by_dates:
        events_by_dates[dt] = []
    events_by_dates[dt].append(event)

# %%
filtered_events = []
for dt, grouped_events in events_by_dates.items():
    initial_len = len(grouped_events)
    if initial_len > 1:
        grouped_events = remove_duplicated(grouped_events)
    filtered_events.extend(grouped_events)

# %%
import random

random.shuffle(filtered_events)
len(filtered_events)
# Out:
# 1495

# %%
events_by_types = {}
for event in filtered_events:
    tags = event['tags']
    for tag in tags:
        if tag not in event_types:
            continue
        
        if tag not in events_by_types:
            events_by_types[tag] = []
        
        if len(events_by_types[tag]) > 200:
            continue
        events_by_types[tag].append(event)

            
reduced_events = []
for _, grouped_event in events_by_types.items():
    reduced_events.extend(grouped_event)
random.shuffle(reduced_events)
len(reduced_events)
# Out:
# 852

# %%
for item in reduced_events:
    if "dates" in item:
        del item["dates"]
    if "poster" in item:
        del item["poster"]
    if "url" in item:
        del item["url"]
    del_none(item)

# %%
save_json("../data/reduced_events.json", reduced_events)

# %%
for event in tg_vk_events:
    event["text"] = preprocess(event["text"])
    
tg_vk_events = [e for e in tg_vk_events if is_suitable_text(e["text"])]

# %%
len(tg_vk_events)
# Out:
# 1010

# %%
tg_vk_event_pairs = [(e, e["text"][:50]) for e in tg_vk_events]
short = [p[1] for p in tg_vk_event_pairs]
short = set(remove_duplicated_texts(short))
tg_vk_events = [e for e, short_e in tg_vk_event_pairs if short_e in short]

# %%
save_json("../data/reduced_events_social.json", tg_vk_events)

# %%
with open("labeled_text", "w+", encoding="utf-8") as f:
    for event in tg_vk_events:
        text = event["text"]
        labeled = {"text": text, "labels": []}
        for string, label in event["labels"]:
            start = text.find(string)
            if start < 0:
                continue
            end = start + len(string)
            labeled["labels"].append((start, end, label))
        f.write(json.dumps(labeled, ensure_ascii=False) + "\n")

# %%
def count_n_grams(n, texts):
    n_grams = {}
    for text in texts:
        for line in text.split('\n'):
            tokens = line.split(' ')
            for i in range(len(tokens) - n + 1):
                n_gram = " ".join(tokens[i:i + n])
                if n_gram not in n_grams:
                    n_grams[n_gram] = 0
                n_grams[n_gram] += 1
    return n_grams

def get_n_grams(n, text):
    tokens = text.split(' ')
    for i in range(len(tokens) - n + 1):
        n_gram = " ".join(tokens[i:i + n])
        yield n_gram

def get_top_n(n_grams, top):
    return sorted([(g, c) for g, c in n_grams.items()], key=lambda p: p[1], reverse=True)[:top]

def combine_tokens(grams):
    grams = list(grams)
    while len(grams) > 0:
        g = grams.pop()
        toks = g.split(' ')
        found = False
        for i, gr in enumerate(grams):
            gr_toks = gr.split(' ')
            if toks[len(toks) - 3:] == gr_toks[:3]:
                common = toks
                common.extend(gr_toks[3:])
                grams.append(" ".join(common))
                del grams[i]
                found = True
                break
            elif toks[:3] == gr_toks[len(gr_toks) - 3:]:
                common = gr_toks
                common.extend(toks[3:])
                grams.append(" ".join(common))
                del grams[i]
                found = True
                break
        if not found:
            yield g
            
def analyze_texts(texts):
    top_20_tri = get_top_n(count_n_grams(5, texts), 200)
    buckets = {}
    for g, c in top_20_tri:
        if c not in buckets:
            buckets[c] = []
        buckets[c].append(g)

    for count, grams in buckets.items():
        if count < 20:
            continue
        combined = list(combine_tokens(grams))
        print(count)
        for gram in sorted(combined, key=lambda p: len(p), reverse=True):
            if len(gram.split(' ')) < 6:
                continue
            print(gram)

# %%
import difflib

def find_place(text, place):
    place_grams = len(place.split(' '))
    matches = []
    for n in range(1, place_grams * 2):
        grams = list(get_n_grams(n, text))
        for gram in grams:
            rate = similar(place, gram)
            if rate > 0.8:
                matches.append((gram, rate))
    if not matches:
        return None
    match = max(matches, key=lambda p: p[1])[0]
    return match

# %%
for event in reduced_events:
    text = event["description"]
    title = event["title"]
    match = find_place(text, title)
    if match:
        print(title)
        print(match)
        print()
# Out:
# Деревянное и каркасное домостроение. Баня-2020
# «Деревянное и каркасное домостроение. Баня-2020»
#
# Okami Anime Party: white
# Okami Anime Party: white
#
# Karaoke
# Karaoke
#
# Стас Михайлов
# Стас Михайлов
#
# Как есть?
# Как есть!
#
# FSP Freaky Summer Party
# Freaky Summer Party
#
# Kostya Outta & QDN
# Kostya Outta DJ QDN
#
# Про Федота-стрельца
# «Про Федота-стрельца»
#
# Хит-коллекция "Территории мюзикла". 90-е
# «Хит-коллекция «Территории мюзикла».
#
# Ilya Rise & QDN
# Ilya Rise - DJ QDN
#
# Открытые экскурсии по выставке «Джаз! Коты! Весна!»
# открытые экскурсии по выставке «Джаз! Коты! Весна!»,
#
# Вода и тепло
# вода и тепло
#
# ''Я вам не скажу за всю Одессу'' Леонид Утесов: вспоминая великого артиста
# «Я вам не скажу за всю Одессу…» Леонид Утёсов: вспоминая великого артиста
#
# Наследники Великой Победы
# «Наследники Великой Победы»
#
# Belphegor
# Belphegor
#
# Гараж
# «Гараж»
#
# Как есть?
# Как есть!
#
# Бой Подушками
# «Бой подушками»
#
# Проект «Lounge Night»
# Проект «Lounge Night»
#
# Пес Белого острова
# «Пёс Белого острова»
#
# Крис Норман
# Крис Норман
#
# «Тает LED»
# «Тает LED»
#
# Хит-коллекция "Территории мюзикла". 90-е
# «Хит-коллекция «Территории мюзикла».
#
# Международный женский день
# Международный женский день
#
# Конференция .NET Summit Belarus 2020
# конференция .NET Summit Belarus 2020
#
# Сальса-вечеринка «Винтажные Грувы»
# сальса-вечеринка «Винтажные Грувы»
#
# Художник, что рисует... Джаз!!!
# «Художник, что рисует… Джаз!!!»
#
# Молодые таланты столицы
# «Молодые таланты столицы»
#
# Дом посреди весны
# «Дом посреди весны»
#
# Дом посреди весны
# «Дом посреди весны»
#
# Хиты оркестра Поля Мориа
# «Хиты оркестра Поля Мориа»
#
# Rubyl'nik meetup #2
# Rubyl'nik meetup .
#
# Stereo Weekend с Новым Радио
# Stereo Weekend с Новым Радио
#
# Симфонические рок-хиты
# «Симфонические рок-хиты.
#
# Исторические концерты. Тимур Сергееня
# "Исторические концерты ". Тимур Сергееня
#
# Охота и рыболовство-2020
# «Охота и рыболовство.
#
# Ярмарка подарков «ГорошекМаркет»
# маркет подарков «Горошек маркет»
#
# OFFMi
# OFFMi.
#
# Мастер-класс по акварели
# мастер-класс по акварели.
#
# УтроВечер
# «УтроВечер»
#
# Квартирник
# «Квартирник».
#
# Спящая красавица
# «Спящая Красавица»
#
# EnoughLove
# «EnoughLove»
#
# Запуск своего проекта: как не затянуть идею в черную дыру (15+)
# «Запуск своего проекта: как не затянуть идею в черную дыру».
#
# Первый стэндап в мире
# «Первый стэндап в мире».
#
# Фабричная девчонка
# «Фабричная девчонка»
#
# Дискотека 90х
# Дискотека 90х!
#
# Концеренция «Цифровой банкинг 2020»
# Конференции «Цифровой банкинг 2020»
#
# Казачий ансамбль "Батька Атаман"
# Казачий ансамбль «Батька Атаман»
#
# Сальса-вечеринка «Винтажные Грувы»
# сальса-вечеринка «Винтажные Грувы»
#
# Волшебство иголочки
# «Волшебство иголочки»
#
# Застигнутые врасплох любовью
# «Застигнутые врасплох любовью»
#
# Принц – золотые уши
# «Принц-золотые уши»
#
# Ночь в гостинице
# "Ночь в гостинице"
#
# 8 Марта с Ансамблем Вооруженных Сил Республики Беларусь
# и танца Вооруженных Сил Республики Беларусь»
#
# Postscriptum: Восточные рабочие в Третьем рейхе
# «Postscriptum: Восточные рабочие в Третьем рейхе».
#
# Выставка эстонских художников
# выставка эстонских художников,
#
# Лекция «Что такое стрит-арт. Учимся разбираться в искусстве улиц»
# лекцию «Что такое стрит-арт. Учимся разбираться в искусстве улиц»,
#
# Опиум
# «Опиум»
#
# Виртуальная реальность в искусстве
# «Виртуальная реальность в искусстве»
#
# Поэзия вышивки
# «Поэзия вышивки»
#
# Любовницы моего мужа
# «Любовницы моего мужа».
#
# Ночь соблазнов
# Ночь соблазнов
#
# Monatik
# Monatik
#
# Минский Вернисаж
# «Минский Вернисаж»
#
# Масленица
# Масленица
#
# Первый стэндап в мире
# «Первый стэндап в мире».
#
# Марк Мартел
# Марк Мартел
#
# Пластический спектакль "Мама"
# пластический спектакль с
#
# Я валяюсь на траве, сто фантазий в голове...
# «Я валяюсь на траве, сто фантазий в голове…»
#
# Презентация книги Владимира Воложинского «Минск в легендах, мифах и преданиях»
# краеведа Владимира Воложинского «Минск в легендах, мифах и преданиях».
#
# Источники света
# «Источники света»
#
# Keep calm and come
# «Keep Calm and Come»
#
# Папа
# Папа
#
# WhiskeyJamBand
# WhiskeyJamBand.
#
# Жан-Поль Готье. С любовью (18+)
# «Жан-Поль Готье. С любовью»
#
# Вячеслав Бутусов
# Вячеслав Бутусов
#
# Про Федота-стрельца
# «Про Федота-стрельца»
#
# Другой. Дорога в Мцхету (0+)
# «Другой. Дорога в Мцхету».
#
# Ирина Аллегрова
# Ирина Аллегрова
#
# Мозгобойня «Назад в 90-е»
# Мозгобойня «Назад в 90-е»
#
# Сколько стоит любовь?
# "Сколько стоит любовь?"
#
# Презентация книги Владимира Воложинского «Минск в легендах, мифах и преданиях»
# краеведа Владимира Воложинского «Минск в легендах, мифах и преданиях».
#
# Мебель & Интерьер. Дизайн и декор
# Мебель & Интерьер. Дизайн. Декор
#
# Спящая красавица
# «Спящая Красавица»
#
# Лесдревтех-2020
# «Лесдревтех-2020»,
#
# Мастер-класс по вокалу
# мастер-класс по вокалу
#
# ''Я вам не скажу за всю Одессу'' Леонид Утесов: вспоминая великого артиста
# «Я вам не скажу за всю Одессу…» Леонид Утёсов: вспоминая великого артиста
#
# Студия «Квартал 95»
# Студия «Квартал 95»
#
# Однажды в Чикаго
# "Однажды в Чикаго"
#
# Другой. Дорога в Мцхету
# «Другой. Дорога в Мцхету».
#
# Твой первый концертный зал (3+)
# «Твой первый концертный зал».
#
# Масленица
# Масленицу
#
# 2040: Будущее ждет (6+)
# «2040: Будущее ждет»
#
# 13Kai & Kassi
# 13Kai & Kassi
#
# С наступающим!
# «С наступающим!»
#
# Вероника решает умереть
# "Вероника решает умереть"
#
# Неделя детей и молодежи 2020
# "Неделя детей и молодежи" –
#
# Семинар Александра Фридмана: «Вы или Хаос: профессиональное планирование для регулярного менеджмента»
# семинаре Александра Фридмана «Вы или Хаос: профессиональное планирование для регулярного менеджмента»,
#
# Ciemra
# Ciemra
#
# Бессрочная акция: Единый билет
# бессрочную акцию «Единый билет»,
#
# Моя собака Идиот (18+)
# «Моя собака Идиот» –
#
# Семинар «Аутсорсинг — современная модель бизнеса»
# семинар «Аутсорсинг — современная модель бизнеса».
#
# Рассмеши любого
# «Рассмеши любого»
#
# Марткоты
# «Марткоты»
#
# Солнечная линия
# "Солнечная линия"
#
# Хаски
# Хаски
#
# Марк Мартел
# Марк Мартел
#
# Семинар «От идеи в резиденты ПВТ. Опыт Aligned Code»
# семинар «От идеи в резиденты ПВТ. Опыт Aligned Code»
#
# Jensen Interceptor
# Jensen Interceptor
#
# Я Моне Я Шишкин Я Малевич (12+)
# «Я Моне Я Шишкин Я Малевич»
#
# Viva la Mamma!
# «Viva la mamma!»
#
# Ночь в гостинице
# "Ночь в гостинице"
#
# От винта!
# «От винта!»
#
# Дискотека 80/90х
# Дискотека 80/90х!
#
# Живая экзотика
# «Живая экзотика».
#
# Конференция «Brands. Fashion. Business»
# Конференция Brands. Fashion. Business
#
# Тоска
# Тоска"
#
# Pavel van Bora & Ilya Rise
# Pavel Van Bora - DJ Ilya Rise
#
# Курс по фотографии Майкла Уилана
# курс фотографии Майкла Уилана.
#
# Как накормить человечество
# «Как накормить человечество».
#
# Top Fest 2020
# Top Fest 2020 –
#
# Bondage Fairies
# Bondage Fairies
#
# Нас поймут через 100 лет. Лазарь Хидекель
# «Нас поймут через 100 лет. Лазарь Хидекель»
#
# Live Lounge
# «Live Lounge»
#
# Метод Гронхольма
# "Метод Гронхольма"
#
# Королевская Масленица
# Королевскую Масленицу
#
# Аквапарк «Дримлэнд»
# Аквапарк Дримлэнд
#
# Женщина мечты
# «Женщина мечты»?
#
# Кот Шредингера
# кот Шрёдингера…
#
# Двое из ларца - одинаковы с лица
# «Двое из ларца - одинаковы с лица».
#
# Женщина мечты
# «Женщина мечты»?
#
# С наступающим!
# «С наступающим!»
#
# Шоу-мюзикл "Стриптиз души"
# шоу-мюзикл «Стриптиз души»
#
# Барды нового века
# «Барды нового века»
#
# Play! История мультфильмов
# «Play! История мультфильмов».
#
# Мебель & Интерьер. Дизайн и декор
# Мебель & Интерьер. Дизайн. Декор
#
# HammAli & Navai
# HammAli & Navai
#
# Петр Клюев
# Петр Клюев
#
# Персональная выставка Таши Коцубы «Home»
# Персональная выставка Таши Коцубы «HOME»
#
# Анна Снегина
# «Анна Снегина»
#
# Дискотека 80/90х
# Дискотека 80/90х!
#
# Первый стэндап в мире
# «Первый стэндап в мире».
#
# Открытая экскурсия Алексея Кузнецова в рамках проекта «Горизонты»
# Работы Алексея Кузнецова, в рамках проекта «Горизонты
#
# Гонка с препятствиями Bison Race
# гонка с препятствиями! Bison Race
#
# CoreHard Spring 2020
# CoreHard Spring 2020
#
#  My Own Private Alaska
# My Own Private Alaska
#
# Комсомольск
# «Комсомольск»
#
# Drozdy Live
# "Drozdy Live".
#
# Большая выставка рептилий
# Большая выставка рептилий
#
# Презентация книги Владимира Воложинского «Минск в легендах, мифах и преданиях»
# краеведа Владимира Воложинского «Минск в легендах, мифах и преданиях».
#
# Polugar acoustic project
# «Polugar acoustic project».
#
# Ilya Rise & Vinyarski
# Ilya Rise - DJ Vinyarski
#
# Глеб Матвейчук
# Глеб Матвейчук
#
# Письмо незнакомки
# "Письмо незнакомки" –
#
# El Gato's 8 dance workshops
# El Gato's 8 dance workshops
#
# Александр Розенбаум
# Александр Розенбаум
#
# Развитие медицины Беларуси с древнейших времен до конца ХХ века
# «Развитие медицины Беларуси с древнейших времен до конца ХХ века»
#
# Product Hunt Stories (18+)
# «Product Hunt Stories»,
#
# Пространство эстонской книги
# «Пространство эстонской книги».
# Семинар «Развитие кадрового потенциала банковского сектора в условиях цифровой трансформации»
# Семинар «Развитие кадрового потенциала банковского сектора в условиях цифровой трансформации»
#
# Viva Braslav Open Air 2020
# Viva Braslav Open Air —
#
# Ансамбль Радзiмiчы
# Ансамбль «Радзiмiчы»
#
# Мастер-класс «Xiaomi Day»
# Мастер-класс "Xiaomi Day"
#
# Эрика Лундмоен
# Эрика Лундмоен
#
# Игорь Христенко
# Игоря Христенко.
#
# Бой Подушками
# «Бой подушками»
#
# Концерт классической музыки "Струнные в Городе"
# концерт классической музыки. «Струнные в Городе» -
#
# Олег Алмазов с моноспектаклем "Разговор в разговоре"
# Олег Алмазов с моноспектаклем «Разговор в разговоре»
#
# Stereo Weekend с Новым Радио
# Stereo Weekend с Новым Радио
#
# Jam Session
# Jam Session!
#
# Караоке в Бруклине
# Караоке в Бруклине
#
# Свадьба в Малиновке
# "Свадьба в Малиновке"
#
# Виртуозы Москвы
# «Виртуозы Москвы»
#
# Анна Снегина
# «Анна Снегина»
#
# Ночь соблазнов
# Ночь соблазнов
#
# The Retuses
# The Retuses
#
# Танцевальный шоу-дуэт Сапфир
# танцевальный шоу-дуэт «Сапфир»,
#
# Colisium Minsk
# Colisium Minsk
#
# О, милый друг!
# "О, милый друг!",
#
# Stereo Weekend с Новым Радио
# Stereo Weekend с Новым Радио
#
# Как накормить человечество
# «Как накормить человечество».
#
# Дискотека на льду
# дискотеки на льду.
#
# Дискотека на льду
# дискотеки на льду.
#
# Группа Операция Пластилин
# группы «Операция Пластилин»,
#
# Котовасия
# «Котовасия»
#
# EnoughLove
# «EnoughLove»
#
# Большая выставка рептилий
# Большая выставка рептилий
#
# И звуками душа слетает с пальцев...
# "И звуками душа слетает с пальцев ..."
#
# Стражи Тадж-Махала
# Стражи Тадж-Махала
#
# Pavel Van Bora & QDN
# Pavel Van Bora - DJ QDN
#
# Ромео и Джульетта
# Ромео и Джульетты
#
# Психологический мастер-класс «Давай дружить»
# Психологический мастер-класс «Давай дружить»
#
# Приключения бременских музыкантов
# приключений бременских музыкантов.
#
# 1/8 финала Телевизионной Международной Лиги КВН
# Телевизионной Международной Лиги МС КВН
#
# Еврейское счастье
# "Еврейское счастье"
#
# Отмена мероприятия
# отмене мероприятия!
#
# Ревизор
# «Ревизор»
#
# Охота и рыболовство-2020
# «Охота и рыболовство.
#
# Москоу дримин
# «Москоу Дримин»
#
# Диско 90х
# «Диско 90-х»
#
# Гонка с препятствиями Bison Race
# гонка с препятствиями! Bison Race
#
# Минский Вернисаж
# «Минский Вернисаж»
#
# Пантера
# Пантера.
#
# Папин Олимпос
# "Папин Олимпос"
#
# Ярмарка подарков «ГорошекМаркет»
# марафон подарков от «Горошек маркет»
#
# Дмитрий Колдун
# Дмитрий Колдун
#
# Медовый месяц
# «Медовый месяц»
#
# Сыграем в дружную семью
# «Сыграем в дружную семью»
#
# Stereo Weekend с Новым Радио
# Stereo Weekend с Новым Радио
#
# Живая экзотика
# «Живая экзотика».
#
# Жанна
# «Жанна»
#
# FSP Freaky Summer Party
# Freaky Summer Party
#
# Лесдревтех-2020
# «Лесдревтех-2020»,
#
# Григорий Лепс
# Григорий Лепс
#
# Keep Calm and Come
# “Keep Calm and Come”
#
# Стендап в Кубе
# "Стендап в Кубе".
#
# playingtheangel
# playingtheangel
#
# Пес Белого острова
# «Пёс Белого острова»
#
# Классическая Мозгобойня
# Классическая Мозгобойня
#
# Академия Баламута
# "Академия Баламута",
#
# Папа
# Папа
#
# На стиле
# «На стиле»
#
# Другой. Дорога в Мцхету
# «Другой. Дорога в Мцхету»
#
# Ночные жители
# «Ночные жители»
#
# Молодые таланты столицы
# «Молодые таланты столицы»
#
# Play! История мультфильмов
# «Play! История мультфильмов».
#
# Государственный академический симфонический оркестр РБ
# Государственного академического симфонического оркестра
#
# Хелависа
# Хелависа
#
# Игорь Растеряев
# Игорь Растеряев:
#
# Karaoke
# Karaoke
#
# Собрание
# «Собрание»
#
# Тараканы
# «Тараканы!»
#
# "Смешной концерт!" с оркестром "Минск-Классик"
# «Смешной концерт!» с оркестром «Минск-Классик»
#
# Мари Краймбрери
# Мари Краймбрери
#
# ПрофиТролли
# «ПрофиТролли»
#
# Бизнес-форум «Номер один» 2020
# бизнес-форум «Номер один» 2020.
#
# Ох и Ах и Гаргамель
# «Ох и Ах и Гаргамель»
#
# Женский сабантуй
# «Женский сабантуй»
#
# Шоу "Однажды в России"
# - «Однажды в России»
#
# Вечер консерватории
# «Вечер консерватории».
#
# Agraba
# Agraba
#
# Реанимация
# Реанимация
#
# Клава Кока
# Клава Кока
#
# Мистер Икс
# Мистер Икс
#
# Страна Енотия
# «Страна Енотия»
#
# CoreHard Spring 2020
# CoreHard Spring 2020
#
# Мэри Поппинс
# Мэри Поппинс
#
# Jensen Interceptor: открытое интервью
# Jensen Interceptor: открытое интервью
#
# Шоу-дуэт Арбат
# шоу-дуэт «Арбат»,
#
# Экономика: перспективы и развитие
# «Экономика: перспективы и развитие»
#
# Дискотека 80/90х
# Дискотека 80/90х!
#
# Мужчины на десерт
# «Мужчины на десерт»
#
# Живая музыка
# живая музыка
#
# Емеля и волшебный камень Радомарин
# Емеля и волшебный камень Радомарин
#
# Kostya Outta & QDN
# Kostya Outta - DJ QDN
#
# Интенсив «Про Свет»
# интенсив “Про Свет”.
#
# Дискотека 90/00х
# Дискотека 90х
#
# Свадьба в Малиновке
# "Свадьба в Малиновке"
#
# Kostya Outta & QDN
# Kostya Outta - DJ QDN
#
# Мартовские коты
# «Мартовские Коты»,
#
# Масленица
# Масленица
#
# Дожить до премьеры
# «Дожить до премьеры»
#
# Nightwish
# Nightwish –
#
# Павел Воля
# Павел Воля
#
# Джаз для детей. Смешные книги и музыка
# «Джаз для детей. Смешные книги и музыка».
#
# Экономика: перспективы и развитие
# «Экономика: перспективы и развитие»
#
# Полина Гагарина
# Полина Гагарина
#
# Большая выставка рептилий
# Большая выставка рептилий
#
# Хит-коллекция "Территории мюзикла". 90-е
# «Хит-коллекция «Территории мюзикла».
#
# Мартовские коты
# «Мартовские коты»,
#
# Ярмарка подарков «ГорошекМаркет»
# маркет подарков «Горошек маркет»
#
# Однажды в Чикаго
# "Однажды в Чикаго"
#
# "Щелкунчик"
# Щелкунчик
#
# Гуси-лебеди
# Гуси-лебеди
#
# Семейный уикенд
# «Семейный уикенд»
#
# Мастер-класс Александра Рогова
# мастер-классом! Александр Рогов
#
# FSP Freaky Summer Party
# Freaky Summer Party
#
# Лекция Валентина Тарасова «Иллюзия звука»
# лекции Валентина Тарасова «Иллюзия звука».
#
# Пигмалион
# «Пигмалион»
#
# Polugar acoustic project
# «Polugar acoustic project».
#
# Тараканы
# «Тараканы!»
#
# Polugar electric project
# «Polugar electric project».
#
# Когда поют сердца
# "Когда поют сердца
#
# Жанна
# «Жанна»
#
# Комсомольск
# «Комсомольск»
#
# Проект «Lounge Night»
# Проект «Lounge Night»
#
# Концерт классической музыки "Струнные в Городе"
# концерт классической музыки. «Струнные в Городе» -
#
# Арт-проект "Три тенора"
# Арт-проекта “Три тенора”
#
# Пространство эстонской книги
# «Пространство эстонской книги».
#
# 7Раса
# 7Раса
#
# Сияние
# Сияние
#
# Банкрот
# «Банкрот»
#
# Трикстер клуб
# «Трикстер клуб»
#
# Наследники Великой Победы
# «Наследники Великой Победы»
#
# Спасибо
# «Спасибо»
#
# Николай Носков
# Николай Носков
#
# Дискотека 90х
# Дискотека 90х!
#
# Баня. Сауна. СПА
# «Баня. Сауна. СПА».
#
# Бурлеск
# «Бурлеск»
#
# Корпоратив
# «Корпоратив»
#
# Сопрано Гоар Акопян (Армения) ''...Святая к Музыке Любовь...''
# сопрано Гоар Акопян (Армения). В рамках концерта «...Святая к Музыке Любовь...»
#
# Павел Воля
# Павел Воля
#
# Любовь и прочее вранье
# «Любовь и прочее враньё».
#
# Белорусский дом
# «Белорусский дом»
#
# Drozdy Live
# «Drozdy Live»
#
# Английская рулетка (Double Double)
# «Английская рулетка (Double Double)»
#
# Элджей
# Элджей
#
# Владимир Ухтинский
# Владимир Ухтинский,
#
# Вячеслав Бутусов
# Вячеслав Бутусов
#
# Чужих мужей не бывает
# «Чужих мужей не бывает» -
#
# Мозгобойня «Назад в 90-е»
# Мозгобойня «Назад в 90-е»
#
# Группа Distemper
# группе Distemper
#
# Художник, что рисует... Джаз
# «Художник, что рисует… Джаз!!!»
#
# DJ Goldscream
# Dj Goldscream.
#
# Конференция .NET Summit Belarus 2020
# конференция .NET Summit Belarus 2020
#
# Стинг
# Стинг
#
# Солнечная линия
# "Солнечная линия"
#
# Подлинная история поручика Ржевского
# "Подлинная история поручика Ржевского"!
#
# Жар-птица
# «Жар-птица»
#
# Мастер-класс по росписи пряников
# мастер-класс по росписи пряников
#
# Top Fest 2020
# Top Fest 2020 –
#
# Эдип
# Эдип
#
# Voxxed Days Minsk
# Voxxed Days Minsk
#
# Високосный год
# «Високосный год»
#
# Мальчишник
# мальчишник
#
# Элджей
# Элджей
#
# Руки Вверх
# «Руки Вверх!»
#
# Семинар «Прийти на выручку или почему рост продаж снова становится главной задачей в стартапах»
# семинар «Прийти на выручку или почему рост продаж снова становится главной задачей в стартапах»
#
# Недвижимость
# “Недвижимость
#
# Женский сабантуй
# «Женский сабантуй»
#
# Элджей
# Элджей
#
# Dj List
# Dj List
#
# Большая выставка рептилий
# Большая выставка рептилий
#
# Красный День Календаря
# «Красный день календаря»
#
# Иоланта
# Иоланта
#
# Шедевры мирового рока
# Шедевры мирового рока
#
# Интеллектуальный бой
# интеллектуальный
#
# Мэвл
# Мэвл
#
# Любовницы моего мужа
# «Любовницы моего мужа».
#
# Валерий Меладзе
# Валерий Меладзе
#
# Приключения бременских музыкантов
# приключений бременских музыкантов.
#
# Марткоты
# «Марткоты»
#
# ''Я вам не скажу за всю Одессу'' Леонид Утесов: вспоминая великого артиста
# «Я вам не скажу за всю Одессу…» Леонид Утёсов: вспоминая великого артиста
#
# Stereo Weekend с Новым Радио
# Stereo Weekend с Новым Радио
#
# Собрание
# «Собрание»
#
# Волшебство иголочки
# «Волшебство иголочки»
#
# DJ List
# Dj List
#
# Спящая красавица
# «Спящая Красавица»
#
# Minsk TRIZ Club #3.6
# Minsk TRIZ Club
# Красный день календаря
# «Красный день календаря».
#
# Нас поймут через 100 лет. Лазарь Хидекель
# «Нас поймут через 100 лет. Лазарь Хидекель»
#
# Открытые экскурсии по выставке «Джаз! Коты! Весна!»
# открытые экскурсии по выставке «Джаз! Коты! Весна!»,
#
# Скейт-музей СССР
# Скейт-музея СССР
#
# MLK+
# MLK+
#
# Музыка кино: Национальный академический народный оркестр Республики Беларусь им. И.Жиновича
# «Музыка кино» в исполнении Национального академического народного оркестра Республики Беларусь им.И.Жиновича
#
# Концеренция «Цифровой банкинг 2020»
# Конференции «Цифровой банкинг 2020»
#
# От винта!
# «От винта!»
#
# Диско 90х
# «Диско 90-х»
#
# «Тает LED»
# «Тает LED»
#
# Вода и тепло
# вода и тепло
#
# Воробьиная ночь
# «Воробьиная ночь»
#
# Стендап в Кубе
# Стендап в Кубе
#
# Postscriptum: Восточные рабочие в Третьем рейхе
# «Postscriptum: Восточные рабочие в Третьем рейхе».
#
# Студия «Квартал 95»
# Студия «Квартал 95»
#
# Рита Дакота
# Риты Дакоты
#
# Территория страсти
# «Территория страсти»
#
# Мэвл
# Мэвл
#
# Реанимация
# Реанимация
#
# Клава Кока
# Клава Кока
#
# Bondage Fairies (16+)
# Bondage Fairies
#
# Fedor Bobrov & Vinyarski
# Fedor Bobrov – DJ Vinyarski
#
# Global Women Forum
# Global Women Forum
#
# Барды нового века
# «Барды нового века»
#
# Сосо Павлиашвили
# Сосо Павлиашвили
#
# Мужчины на десерт
# «Мужчины на десерт»
#
# Интенсив «Про Свет»
# интенсив “Про Свет”.
#
# Варшавская мелодия
# «Варшавская мелодия»
#
# В поисках истинного Я
# В поисках истинного Я»
#
# Дискотека 90/00х
# Дискотека 90х
#
# Шоу «Иллюзионисты будущего»
# "Иллюзионисты будущего"!
#
# Джизус
# Джизуса,
#
# 65daysofstatic
# 65daysofstatic
#
# Деревянное и каркасное домостроение. Баня-2020
# «Деревянное и каркасное домостроение. Баня-2020»
#
# Жека. Евгений Григорьев
# Евгений Григорьев
#
# Любовь втроем
# «Любовь втроём»
#
# Комната умирает
# "Комната умирает",
#
# Kids Fashion Show
# Kids Fashion Show
#
# Я валяюсь на траве, сто фантазий в голове
# «Я валяюсь на траве, сто фантазий в голове…»
#
# Виртуальная реальность в искусстве
# «Виртуальная реальность в искусстве»
#
# Академический ансамбль песни и танца Вооруженных сил Республики Беларусь
# "Академический ансамбль песни и танца Вооруженных Сил Республики Беларусь"
#
# Top Fest 2020
# Top Fest 2020 –
#
# Софья Гольшанская
# "Софья Гольшанская"
#
# Drozdy Live
# «Drozdy Live»
#
# С училища
# "С училища"
#
# Voxxed Days Minsk
# Voxxed Days Minsk
#
# Черный монах
# Чёрный монах
#
# Дети Ванюшина
# «Дети Ванюшина»
#
# Patsinka
# «Patsinka»
#
# Тренинг «Java Web Development»
# тренинг Java Web Development
#
# ''Я вам не скажу за всю Одессу'' Леонид Утесов: вспоминая великого артиста
# «Я вам не скажу за всю Одессу…» Леонид Утёсов: вспоминая великого артиста
#
# Открытая экскурсия Алексея Кузнецова в рамках проекта «Горизонты»
# Работы Алексея Кузнецова, в рамках проекта «Горизонты
#
# Misþyrming
# Misþyrming
#
# Ilya Rise & VINYARSKI
# Ilya Rise - DJ VINYARSKI
#
# Белорусский дом
# «Белорусский дом»
#
# Вокруг Света за 90 дней. Африка
# «Вокруг Света за 90 дней. Африка».
#
# Группа "Пионерлагерь Пыльная Радуга"
# Пионерлагерь Пыльная Радуга
#
# Дмитрий Быков
# Дмитрий Быков
#
# Недвижимость
# “Недвижимость
#
# Дискотека 90х
# Дискотека 90х!
#
# Страна Енотия
# «Страна Енотия»
#
# «Как важно быть серьезным»
# «Как важно быть серьёзным»
#
# Трикстер клуб
# «Трикстер клуб»
#
# Сальса-вечеринка «Винтажные Грувы»
# сальса-вечеринка «Винтажные Грувы»
#
# Minsk iGaming Affiliate Conference
# Minsk iGaming Affiliate Conference
#
# Среда обитания
# среде обитания,
#
# Мужчины на десерт
# «Мужчины на десерт»
#
# Белорусский дом
# «Белорусский дом»
#
# Kanama (The Garden / Kharkiv)
# Kanama (The Garden / Kharkiv)
#
# Руслан Алехно
# Руслан Алехно
#
# Муза. Музыка. Моцарт
# «Муза. Музыка. Моцарт»
#
# Юрий Северин
# Юрия Северина
#
# Когда же пойдет снег?
# "Когда же пойдет снег...?"
#
# Семен Альтов
# Семен Альтов —
#
# Группа Nothing But Thieves
# рок-группа Nothing But Thieves.
#
# Тоска
# Тоска"
#
# Ярмарка подарков «ГорошекМаркет»
# марафон подарков от «Горошек маркет»
#
# Развитие медицины Беларуси с древнейших времен до конца ХХ века
# «Развитие медицины Беларуси с древнейших времен до конца ХХ века»
#
# Тренинг «Professional Agile Leadership — Essentials»
# Professional Agile Leadership - Essentials
#
# Барды нового века
# «Барды нового века»
#
# Игорь Христенко
# Игоря Христенко.
#
# Сальса-вечеринка «Винтажные Грувы»
# сальса-вечеринка «Винтажные Грувы»
#
# Каста
# Каста
#
# Баня. Сауна. СПА
# «Баня. Сауна. СПА».
#
# Хадн Дадн
# Хадн дадн
#
# Скейт-музей СССР
# Скейт-музея СССР
#
# Музыки эпох барокко и романтизма: Возвышенное и земное. Лёд и пламень
# музыки эпох барокко и романтизма «Возвышенное и земное. Лёд и пламень»

# %%
reduced_events[163]
# Out:
# {'title': 'Оскар и Розовая Дама',
#  'description': 'История о Мальчике и Розовой Даме - это история о двух людях, рассказ о двух мирах. Никто не знает, где в нём заканчивается правда и начинается фантазия, потому что жизнь сплетается в сложный клубок реальных трагедий и вымышленных образов. Как можно в 10 лет решить то, что многим не под силу в 50? Как можно подарить утешение и надежду на жизнь, когда ты стоишь на пороге неизбежного? Это рассказ о жизни и смерти, правде и лжи, отчаянии и надежде. История о каждом из нас, о том, что важно и ценно.',
#  'place': {'name': 'Театр им. М. Горького',
#   'address': 'г. Минск, ул. Володарского, 5',
#   'url': 'https://afisha.tut.by/place/teatr-gorkogo/'},
#  'tags': ['Спектакль']}
