# %%
import json 

def load_json(filename):
    with open(filename, "r", encoding="utf-8") as f:
        return json.load(f)
    
def save_json(filename, obj):
    with open(filename, "w+", encoding="utf-8") as f:
        return json.dump(obj, f, ensure_ascii=False, indent=4) 
    
def load_file(filename):
    return list(open(filename, encoding="utf-8").readlines())


def del_none(d):
    for key, value in list(d.items()):
        if value is None or value == "":
            del d[key]
        elif isinstance(value, dict):
            del_none(value)
    return d

# %%
event_types = load_json("../data/unified.json")["types"]

# %%
tut = load_json("../data/tutby.json")
cd = load_json("../data/citydog.json")
relax = load_json("../data/relax.json")
old_events = load_json("../data/events.json")

events = []
events.extend(tut)
events.extend(cd)
events.extend(relax)
events.extend(old_events)

# %%
len([event['place'] for event in events if 'address' not in event['place']])
# Out:
# 0

# %%
places = {}
for event in events:
    place = event['place']
    address = place['address']
    if address not in places:
        places[address] = set()
    places[address].add(place['name'])
for key, value in places.items():
    places[key] = list(places[key])

# %%
save_json("../data/places.json", places)

# %%
tg_vk_events = []
for e in load_file("../labeled_text"):
    labeled_event = json.loads(e)
    delabled_event = {"text": labeled_event["text"], "labels": []}
    for start, end, label in labeled_event["labels"]:
        delabled_event["labels"].append((labeled_event["text"][start:end], label))
    tg_vk_events.append(delabled_event)

# %%
import re
import urlextract
url_extractor = urlextract.URLExtract()
        
freq = [
    "работая с артистами, которых ранее никому не удавалось привезти в Беларусь -",
    "Минские организаторы, не перестают радовать Белорусских фанатов,",
    "Минские организаторы, не перестают радовать фанатов,",
    "Baby Tape, Boulevard Depo, Loqiemean, Jeembo &",
    "Билеты можно приобрести онлайн на AFISHA.TUT.BY",
    "Билеты можно купить онлайн на AFISHA.TUT.BY",
    "Фото и видео",
    "Depo, Loqiemean, Jeembo &",
    "на AFISHA.TUT.BY Фото и видео",
    "О событии"
]

space_re = re.compile(r"[\s|\u2800]+")
comma_re = re.compile(r"(([^\d])\s*,\s*(\w))")
comma_re_2 = re.compile(r"((\w)\s*,\s*([^\d]))")
dash_re = re.compile(r"(([^\d])\s*\-+\s*([^\d]))")
underscore_re = re.compile(r"\_+")
hashtag_re = re.compile(r"#\w+")


def remove_urls(text):
    urls = list(set(url_extractor.find_urls(text)))
    urls.sort(key=lambda u: len(u), reverse=True)
    for url in urls:
        text = text.replace(url, "")
    return text

def preprocess(text):
    text = text.replace("\n", " ")
    text = remove_urls(text)
    text = hashtag_re.sub("", text)
    text = underscore_re.sub(" ", text)
    for f in freq:
        text = text.replace(f, "")
    for whole, first, second in reversed(comma_re.findall(text)):
        text = text.replace(whole, "%s, %s" % (first, second))
    for whole, first, second in reversed(comma_re_2.findall(text)):
        text = text.replace(whole, "%s, %s" % (first, second))
    text = space_re.sub(" ", text)
    return text.strip()

# %%
for e in events:
    text = e['description']
    e['description'] = preprocess(text)

# %%
def detect_lang(text):
    by_letters = ['і', 'ў', 'шч']
    for by_letter in by_letters:
        if by_letter in text:
            return "by"
    return "ru"

def is_suitable_text(text):
    if detect_lang(text) == "by":
        return False
    if len(text) > 2000 or len(text) < 80:
        return False
    if all(not c.isdigit() for c in text):
        return False
    return True

# %%
events = [e for e in events if is_suitable_text(e['description'])]

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
import numpy as np

def remove_duplicated_texts(evs):
    removed_idx = set()
    unique_events = []
    for i, current_text in enumerate(evs):
        if i in removed_idx:
            continue
            
        duplicates = [current_text]
        for j, text in enumerate(evs[i + 1:]):
            if j in removed_idx:
                continue
            res = similar(current_text, text)
            if res > 0.6:
                duplicates.append(text)
                removed_idx.add(j)
                
        unique_event = max(duplicates, key=lambda e: len(e))
        unique_events.append(unique_event)
        
    return unique_events

def remove_duplicated(evs):
    removed_idx = set()
    unique_events = []
    for i, current_event in enumerate(evs):
        if i in removed_idx:
            continue
            
        duplicates = [current_event]
        for j, event in enumerate(evs[i + 1:]):
            if j in removed_idx:
                continue
            res = similar(current_event['description'], event['description'])
            if res > 0.6:
                duplicates.append(event)
                removed_idx.add(j)
                
        unique_event = max(duplicates, key=lambda e: len(e['description']))
        unique_events.append(unique_event)
        
    return unique_events

# %%
import random
import datetime

def group_by_dates(events):
    events_by_dates = {}
    for event in events:
        date = event['dates'][0]
        if 'start' in date:
            date = date['start']
        if date:
            if "hour" in date:
                dt = datetime.datetime(year=date['year'], month=date['month'], day=date['day'], hour=date['hour'], minute=date['minute'])
            else:
                dt = datetime.date(year=date['year'], month=date['month'], day=date['day'])
        else:
            dt = datetime.date(year=datetime.MINYEAR, month=1, day=1)

        if dt not in events_by_dates:
            events_by_dates[dt] = []
        events_by_dates[dt].append(event)
    return events_by_dates

def group_by_place(events):
    events_by_place = {}
    for event in events:
        place = event['place']['name']
        if place not in events_by_place:
            events_by_place[place] = []
        events_by_place[place].append(event)
    return events_by_place

# %%
filtered_events = []
for dt, grouped_events in events_by_dates.items():
    initial_len = len(grouped_events)
    if initial_len > 1:
        grouped_events = remove_duplicated(grouped_events)
    filtered_events.extend(grouped_events)

# %%
import random

random.shuffle(filtered_events)
len(filtered_events)

# %%
events_by_types = {}
for event in filtered_events:
    tags = event['tags']
    for tag in tags:
        if tag not in event_types:
            continue
        
        if tag not in events_by_types:
            events_by_types[tag] = []
        
        if len(events_by_types[tag]) > 200:
            continue
        events_by_types[tag].append(event)

            
reduced_events = []
for _, grouped_event in events_by_types.items():
    reduced_events.extend(grouped_event)
random.shuffle(reduced_events)
len(reduced_events)

# %%
for item in reduced_events:
    if "dates" in item:
        del item["dates"]
    if "poster" in item:
        del item["poster"]
    if "url" in item:
        del item["url"]
    del_none(item)

# %%
save_json("../data/reduced_events.json", reduced_events)

# %%
for event in tg_vk_events:
    event["text"] = preprocess(event["text"])
    
tg_vk_events = [e for e in tg_vk_events if is_suitable_text(e["text"])]

# %%
len(tg_vk_events)

# %%
tg_vk_event_pairs = [(e, e["text"][:50]) for e in tg_vk_events]
short = [p[1] for p in tg_vk_event_pairs]
short = set(remove_duplicated_texts(short))
tg_vk_events = [e for e, short_e in tg_vk_event_pairs if short_e in short]

# %%
save_json("../data/reduced_events_social.json", tg_vk_events)

# %%
with open("labeled_text", "w+", encoding="utf-8") as f:
    for event in tg_vk_events:
        text = event["text"]
        labeled = {"text": text, "labels": []}
        for string, label in event["labels"]:
            start = text.find(string)
            if start < 0:
                continue
            end = start + len(string)
            labeled["labels"].append((start, end, label))
        f.write(json.dumps(labeled, ensure_ascii=False) + "\n")

# %%
def count_n_grams(n, texts):
    n_grams = {}
    for text in texts:
        for line in text.split('\n'):
            tokens = line.split(' ')
            for i in range(len(tokens) - n + 1):
                n_gram = " ".join(tokens[i:i + n])
                if n_gram not in n_grams:
                    n_grams[n_gram] = 0
                n_grams[n_gram] += 1
    return n_grams

def get_n_grams(n, text):
    tokens = text.split(' ')
    for i in range(len(tokens) - n + 1):
        n_gram = " ".join(tokens[i:i + n])
        yield n_gram

def get_top_n(n_grams, top):
    return sorted([(g, c) for g, c in n_grams.items()], key=lambda p: p[1], reverse=True)[:top]

def combine_tokens(grams):
    grams = list(grams)
    while len(grams) > 0:
        g = grams.pop()
        toks = g.split(' ')
        found = False
        for i, gr in enumerate(grams):
            gr_toks = gr.split(' ')
            if toks[len(toks) - 3:] == gr_toks[:3]:
                common = toks
                common.extend(gr_toks[3:])
                grams.append(" ".join(common))
                del grams[i]
                found = True
                break
            elif toks[:3] == gr_toks[len(gr_toks) - 3:]:
                common = gr_toks
                common.extend(toks[3:])
                grams.append(" ".join(common))
                del grams[i]
                found = True
                break
        if not found:
            yield g
            
def analyze_texts(texts):
    top_20_tri = get_top_n(count_n_grams(5, texts), 200)
    buckets = {}
    for g, c in top_20_tri:
        if c not in buckets:
            buckets[c] = []
        buckets[c].append(g)

    for count, grams in buckets.items():
        if count < 20:
            continue
        combined = list(combine_tokens(grams))
        print(count)
        for gram in sorted(combined, key=lambda p: len(p), reverse=True):
            if len(gram.split(' ')) < 6:
                continue
            print(gram)

# %%
import difflib

def find_place(text, place):
    place_grams = len(place.split(' '))
    matches = []
    for n in range(1, place_grams * 2):
        grams = list(get_n_grams(n, text))
        for gram in grams:
            rate = similar(place, gram)
            if rate > 0.8:
                matches.append((gram, rate))
    if not matches:
        return None
    match = max(matches, key=lambda p: p[1])[0]
    return match

# %%
for event in reduced_events:
    text = event["description"]
    title = event["title"]
    match = find_place(text, title)
    if match:
        print(title)
        print(match)
        print()

# %%
reduced_events[163]

# %%
embeddings = {}
with open("") as f:
    for line in f:
        word, *vector = line.split(',')
        vector = [float(v) for v in vector]
        embeddings[word] = np.array(vector)
        
def get_vector(word):
    if word in embeddings:
        return embeddings[word]
    new_vector = np.random.rand(2048)
    embeddings[word] = new_vector
    return new_vector

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")
from nltk.tokenize import word_tokenize


from pymystem3 import Mystem
from string import punctuation

mystem = Mystem()
def preprocess_text(text):
    tokens = word_tokenize(text.lower()) #mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords\
              and token != " " \
              and token.strip() not in punctuation]
    
    #text = " ".join(tokens)
    
    return tokens

# %%
import sys
import re
import os
import numpy as np
import tensorflow as tf
from bilm import Batcher, BidirectionalLanguageModel, weight_layers
from sklearn import preprocessing


def tokenize(string):
    """
    :param string: well, text string
    :return: list of tokens
    """
    token_pattern = re.compile('(?u)\w+')
    tokens = [t.lower() for t in token_pattern.findall(string)]
    return tokens


def get_elmo_vectors(sess, texts, batcher, sentence_character_ids, elmo_sentence_input):
    """
    :param sess: TensorFlow session
    :param texts: list of sentences (lists of words)
    :param batcher: ELMo batcher object
    :param sentence_character_ids: ELMo character id placeholders
    :param elmo_sentence_input: ELMo op object
    :return: embedding matrix for all sentences (max word count by vector size)
    """

    # Create batches of data.
    sentence_ids = batcher.batch_sentences(texts)
    print('Sentences in this batch:', len(texts), file=sys.stderr)

    # Compute ELMo representations.
    elmo_sentence_input_ = sess.run(elmo_sentence_input['weighted_op'],
                                    feed_dict={sentence_character_ids: sentence_ids})

    return elmo_sentence_input_


def get_elmo_vector_average(sess, texts, batcher, sentence_character_ids, elmo_sentence_input):
    vectors = []

    # Create batches of data.
    sentence_ids = batcher.batch_sentences(texts)
    print('Sentences in this chunk:', len(texts), file=sys.stderr)
    # Compute ELMo representations.
    elmo_sentence_input_ = sess.run(elmo_sentence_input['weighted_op'],
                                    feed_dict={sentence_character_ids: sentence_ids})
    print('ELMo sentence input shape:', elmo_sentence_input_.shape, file=sys.stderr)
    for sentence in range(len(texts)):
        sent_vec = np.zeros((elmo_sentence_input_.shape[1], elmo_sentence_input_.shape[2]))
        for word_vec in enumerate(elmo_sentence_input_[sentence, :, :]):
            sent_vec[word_vec[0], :] = word_vec[1]
        semantic_fingerprint = np.sum(sent_vec, axis=0)
        semantic_fingerprint = np.divide(semantic_fingerprint, sent_vec.shape[0])
        query_vec = preprocessing.normalize(semantic_fingerprint.reshape(1, -1), norm='l2')
        vectors.append(query_vec.reshape(-1))
    return vectors


def load_elmo_embeddings(directory, top=False):
    """
    :param directory: directory with an ELMo model ('model.hdf5', 'options.json' and 'vocab.txt.gz')
    :param top: use ony top ELMo layer
    :return: ELMo batcher, character id placeholders, op object
    """
    if os.path.isfile(os.path.join(directory, 'vocab.txt.gz')):
        vocab_file = os.path.join(directory, 'vocab.txt.gz')
    elif os.path.isfile(os.path.join(directory, 'vocab.txt')):
        vocab_file = os.path.join(directory, 'vocab.txt')
    else:
        raise SystemExit('Error: no vocabulary file found in the directory.')
    options_file = os.path.join(directory, 'options.json')
    weight_file = os.path.join(directory, 'model.hdf5')

    # Create a Batcher to map text to character ids.
    batcher = Batcher(vocab_file, 50)

    # Input placeholders to the biLM.
    sentence_character_ids = tf.compat.v1.placeholder('int32', shape=(None, None, 50))

    # Build the biLM graph.
    bilm = BidirectionalLanguageModel(options_file, weight_file, max_batch_size=128)

    # Get ops to compute the LM embeddings.
    sentence_embeddings_op = bilm(sentence_character_ids)

    # Get an op to compute ELMo (weighted average of the internal biLM layers)
    elmo_sentence_input = weight_layers('input', sentence_embeddings_op, use_top_only=top)
    return batcher, sentence_character_ids, elmo_sentence_input


def divide_chunks(data, n):
    for i in range(0, len(data), n):
        yield data[i:i + n]

# %%
sentences = [
    'Состоится концерт группы The Feedback',
    'Группа The Feedback отыграет концерт',
    'Приходите на концерт группы The Feedback',
    'Концерт группы The Beatles',
    'Концерт группы The Feedback'
]
sentences = [tokenize(s) for s in sentences]

# %%
batcher, sentence_character_ids, elmo_sentence_input = load_elmo_embeddings("C:/Users/ASUS/Downloads/199")
# Out:
# WARNING:tensorflow:From c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\bilm\model.py:522: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\bilm\model.py:567: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
def get_vectors(sentences):
    with tf.compat.v1.Session() as sess:
        # It is necessary to initialize variables once before running inference.
        sess.run(tf.compat.v1.global_variables_initializer())
        elmo_vectors = get_elmo_vectors(sess, sentences, batcher, sentence_character_ids, elmo_sentence_input)
        return elmo_vectors

# %%
def print_heat_matrix(vectors):
    size = len(vectors)
    heat_matrix = np.zeros((size, size))
    for i in range(size):
        for j in range(size):
            if i == j:
                heat_matrix[i][j] = 0
            else:
                heat_matrix[i][j] = compute_distance(vectors[i], vectors[j])
    print(heat_matrix)
    
def print_heat_matrix_text(sentences):
    size = len(sentences)
    heat_matrix = np.zeros((size, size))
    for i in range(size):
        for j in range(size):
            if i == j:
                heat_matrix[i][j] = 0
            else:
                heat_matrix[i][j] = similar(sentences[i], sentences[j])
    print(heat_matrix)

# %%
import scipy

def compute_distance(vector1, vector2):
    vector_1 = np.mean(vector1, axis=0)
    vector_2 = np.mean(vector2, axis=0)
    cosine = scipy.spatial.distance.cosine(vector_1, vector_2)
    return cosine

def count_heat(vector_1, vector_2):
    heat_matrix = np.zeros((len(vector_1), len(vector_2)))
    for i in range(len(vector_1)):
        v1 = vector_1[i]
        for j in range(len(vector_2)):
            v2 = vector_2[j]
            heat_matrix[i][j] = round(scipy.spatial.distance.cosine(v1, v2), 3)
    return heat_matrix

# %%
count_heat(elmo_vectors[0], elmo_vectors[1])
# Out:
# array([[0.664, 0.786, 0.721, 0.516, 0.663, 1.041],
#        [0.529, 0.809, 0.693, 0.574, 0.111, 1.06 ],
#        [0.284, 0.715, 0.659, 0.664, 0.513, 0.984],
#        [0.761, 0.081, 0.491, 0.758, 0.739, 1.047],
#        [0.707, 0.457, 0.079, 0.655, 0.611, 0.953],
#        [1.064, 1.044, 0.959, 1.103, 1.057, 0.   ]])

# %%
len(events)
# Out:
# 3211

# %%
events_by_dates = group_by_dates(events)

# %%
for date, date_events in events_by_dates.items():
    events_by_place = group_by_place(date_events)
    for place, place_events in events_by_place.items():
        if len(place_events) > 1:
            texts = list(set([preprocess(e['description']) for e in place_events]))
            if len(texts) == 1:
                continue
            for t in texts:
                print(t)
                print()
            #vectors = get_vectors(texts)
            print_heat_matrix_text(texts)
            print("\n\n")
# Out:
#
# [[0.         0.17996357]
#  [0.1989071  0.        ]]
#
#
#
# Стоимость: 15р. Заснеженный горный отель. Съёмки голливудского блокбастера. Режиссёр найден мёртвым. Может быть, ты что-то видел? Может быть, ты знаешь убийцу? Или, может быть, ТЫ это сделал? Запись обязательна. Справки по телефонам +375(29) 779 57 57, +375(44) 771 57 57
#
# Сегодня утром съёмочная группа прибыла в отель «Белоснежный Приют», где по сюжету фильма произошло убийство. Встречая гостей, хозяин отеля рассказал, что именно здесь 15 лет назад один из постояльцев сошёл с ума и зарубил топором жену и её любовника — хотя некоторые заподозрили, что это вымысел для раскрутки отеля. Шутки закончились, когда произошло настоящее убийство. Жертвой оказался сам режиссёр — Стивен Сайник! Вам предстоит продолжить съёмки фильма, разоблачить грязные тайны съёмочной группы, собрать улики, понять, кому выгодно было убить режиссёра, и вычислить убийцу. А если убийца вы — запутать следы и сбить следствие с толку. Жанр: Камерный детектив Время действия: Наши дни Пожелание к одежде: Одежда, соответствующая атмосфере заснеженного отеля и съёмок фильма: свитера, шарфы, лыжи;) или эксцентричный стиль деятелей искусства - береты, яркая одежда Игра вызовет восторг, если вы: — Любите пробовать новые форматы развлечения; — Кайфуете от общения с интересными людьми; — Мечтали почувствовать себя героем книги/фильма, пережив историю на себе или сделав ее лучше. Место проведения: Игровое пространство "Квест кафе", ул.Сухая, д.4, пом.115 Стоимость: В день мероприятия, на месте - 15 руб. Попасть на игру: Позвонить по телефону +375 29 779-57-57, +375 44 771-57-57
#
# [[0.         0.0872914 ]
#  [0.05006418 0.        ]]
#
#
#
# «Академия коммуникации» – проект, созданный кафедрой технологий коммуникации и связей с общественностью факультета журналистики БГУ. Это отличная возможность для каждого желающего, вне зависимости от возраста и профессии, изучить сферу коммуникации: PR, рекламу, маркетинг, брендинг и журналистику. Проект включает серию занятий, которые проводятся 1 раз в неделю. Тема очередного занятия: «Запуск своего проекта: как не затянуть идею в черную дыру». Спикер встречи – Дарья Герасименко, контент-продюсер Skyeng, создатель и организатор проекта «Креатон», куратор блока «Креатив» в Икре. Дарья точно знает, как создать крутую идею, и поделится лучшими кейсами из своей практики. У вас есть идея для крутого социального проекта? Тогда мы расскажем, как воплотить ее в жизнь.
#
# 27 февраля "Академия коммуникации" приглашает на новую встречу. «Академия коммуникации» – проект, созданный кафедрой технологий коммуникации и связей с общественностью факультета журналистики БГУ. Это отличная возможность для каждого желающего, вне зависимости от возраста и профессии, изучить сферу коммуникации: PR, рекламу, маркетинг, брендинг и журналистику. Проект включает серию занятий, которые проводятся 1 раз в неделю.Тема 9 занятия: "Запуск своего проекта: как не затянуть идею в черную дыру". Спикер встречи – Дарья Герасименко, контент-продюсер Skyeng, создатель и организатор проекта "Креатон", куратор блока "Креатив" в Икре. Дарья точно зн
уске широкого спектра гигиенических салфеток, чистящих средств и бытовой химии. Продукция компании выпускается под широко известными на рынке брендами: « AQUA VIVA », «ПапаМама», « Zala ». Академия «Талантвилль» — детский развивающий центр, где ребенок с 2 лет может не только всесторонне развиваться и обучаться, но и найти первых верных друзей. ТЦ «Квадро» — место не только приятных и нужных покупок, но и атмосфера праздника, который не оставляет равнодушными своих покупателей. Дата и время проведения: 7 марта с 14.00 до 16.00 по адресу: г. Минск, ул. Налибокская, 36.
#
# 7 марта в торговом центре «Квадро» проводят праздник «Международный Женский день». Данное мероприятие проводится для всех желающих детей и взрослых, которые хотят собственными руками совместно с детским центром «Талантвилль» изготовить для своих сестер, матерей и бабушек открытки и поделки для слабой половины, чтобы потом подарить их своим дорогим и любящим их женщинам. На данное мероприятие приглашаются все: как прекрасная половина, так и мужественные и брутальные мальчики, ведь у всех есть матери, бабушки, которым будет приятно получить подарок в этот особенный день. Уверены, что подарок, который будет сделан собственноручно будет оценен по достоинству. Надеемся, что каждый ребенок получит массу положительных эмоций, которые надолго сохранятся от этого веселого праздника. Дата и время проведения: 7 марта с 14.00 до 16.00 по адресу: г. Минск, ул. Налибокская, 36.
#
# [[0.         0.54566474]
#  [0.65433526 0.        ]]
#
#
#
# Направление тренинга Бизнес анализ в IT – важный этап создания информационной системы, где согласуется видение системы со стороны заказчика и команды разработки, формируются требования и проектируется решение. Требования к кандидатам — Английский язык уровня B2 или выше — Аналитическое мышление — Коммуникативные навыки — Понимание роли бизнес-аналитика на проекте — Наличие времени для выполнения домашних заданий Описание тренинга Тренинг дает базовый набор знаний и навыков для будущих бизнес-аналитиков в IT, а также знакомит с основным бизнес-аналитическим инструментарием, дает обзор аналитических активностей и роли бизнес-аналитика на IT-проекте. Особое внимание курс уделяет написанию требований – этот навык необходим Junior бизнес-аналитику и позволяет сразу же применить полученные знания на практике. Для того чтобы понять рабочее окружение бизнес-аналитика участники тренинга познакомятся с процессом разработки программного обеспечения и его реализацией в водопадных и гибких моделях разработки. Программа тренинга включает теоретическую и практическую части, а также домашнюю работу. Cлушатели получают обратную связь и рекомендации по результатам своих работ. При успешном обучении участники тренинга могут присоединиться к EPAM BA Lab с возможностью получить Job Offer в компанию. Подать заявку на тренинг можно здесь ! Место проведения: Минск, Минск, ул. Тиражная 150
#
# Направление тренинга Язык с богатой историей и широкой областью применения, который позволяет делать действительно качественные продукты в короткий промежуток времени. Ruby отличается высокой скоростью разработки и огромным количеством библиотек, готовых к использованию. Требования к кандидатам — Базовые знания SQL, Ruby, Git — Навыки программирования — Уровень английского языка от A2 (Pre-Intermediate) — Иметь с собой ноутбук с ОС Linux/MacOS Описание тренинга Тренинг позволяет изучить не только основы Ruby, но и дает возможность поучаствовать в разработке полноценного веб-приложения. Мы изучим экосистему Ruby, техники написания чистого и поддерживаемого кода, а также познакомимся с базовыми понятиями архитектуры современных веб-приложений с использованием облачных технологий. Подать заявку на тренинг можно здесь ! Место проведения: Минск, Минск, ул. Ак.Купревича 1/5
#
# Направление тренинга Тестирование ПО – это непрерывная борьба за качество. Зачастую, именно работа тестировщика определяет счастье конечного пользователя. Требования к кандидатам До регистрации на тренинг нужно: — прочесть книгу Святослава Куликова Тестирование программного обеспечения. Базовый курс и Романа Савина "Тестирование.com" — иметь уровень разговорного английского от B1 (Intermediate) и выше — понимать основные процессы тестирования и обладать отличными коммуникативными способностями — иметь возможность приступить к стажировке в лаборатории (полный рабочий день) не позже чем через 6 недель после окончания тренинга Описание тренинга Тренинг позволит разобраться в процессе тестирования и изучить широкий спектр сопутствующих технологий. Все теоретические вопросы будут закреплены на практике, охватывающей ключевые виды деятельности тестировщика. Программа обучения включает основы функционального тестирования, работу с документацией, поиск и документирование дефектов. В конце тренинга часть внимания уделяется основам автоматизиорванного тестирования с использованием Selenium IDE и тестированию производительности. Подать заявку на тренинг можно здесь ! Место проведения: Минск, Минск, ул. Ак.Купревича 1/2
#
# [[0.         0.09351566 0.03596021]
#  [0.04322894 0.         0.18509729]
#  [0.04667177 0.15092549 0.        ]]
#
#
#
# Java входит в первую тройку самых распространенных языков программирования и предназначен для разработки приложений уровня корпорации. Требования к кандидатам — Базовые навыки программирования на ООП языках (Java предпочтительнее) — Знание и опыт работы с объектно-ориентированным дизайном будет преимуществом — Базовые навыки в РСУБД — Уровень английского: A2 (Pre-Intermediate) для студентов и B1 (Intermadiate) для выпускников. Описание тренинга Бесплатный тренинг Java Web Development - это введение в разработку программного обеспечения на языке программирования Java и связанных с ним технологиях. Курс предназначен для кандидатов с небольшим опытом программирования, участники тренинга познакомятся с основами Java и Java Web. Подать заявку на тренинг можно здесь ! Место проведения: Минск, Купревича 1\2
#
# Напревление тренинга SAP - это современные технологии разработки приложений на платформах SAP, мирового лидера в области корпоративных решений для ведения и управления бизнесом. Требования к кандидатам Высшее техническое образование или студенты 3-4 курса IT-специальностей Экономический уклон в образовании будет плюсом Знакомство с одним или несколькими языками программирования на уровне написания небольших программ Английский язык уровня Pre-intermediate (А2) и выше Описание тренинга SAP – крупнейший производитель программного обеспечения для бизнеса по версии Forbes. Больше 60% европейского и 50% американского рынка используют продукты SAP. В числе клиентов настоящие акулы: Adidas, Google, Coca-Cola, Volkswagen. Мы проводим тренинг для желающих начать работу в этом направлении. Через наши лаборатории прошли 250+ будущих SAP-инженеров и SAP-консультантов. Кто-то за это время стал проектным менеджером, тим лидом или архитектором, а кое-кто даже директором. Программа включает изучение современных технологий разработки ПО в средах SAP ECC, SAP S/4HANA, SAP HANA и SAP Cloud Platform. После окончания курса у тебя будут твердые навыки программирования на языке ABAP OO. Обучение проходит в blended-формате: 1 Stage - Online-тренинг, 2 Stage - обучение в лабе с возможностью получить Job Offer в EPAM (для перехода на этот этап необходимо пройти технический тест). Подать заявку на тренинг можно здесь ! Место проведения: Минск, ул. Купревича, 1/5
#
# [[0.         0.03259912]
#  [0.02202643 0.        ]]

# %%
scipy.spatial.distance.cosine([-11, 32, 322], [1, 1, 1])
# Out:
# 0.38836437773614707
