# %%
streets = []
with open("C:\\Research\\Events\\data\\streets.tsv", "r", encoding="utf-8") as f:
    for line in f:
        values = line.strip().split('\t')
        if len(values) == 1:
            values = values[0].split(' ')
            values = [' '.join]
        streets.append((values[0], values[1]))

# %%
import requests
import json

# %%
with open("..//data//places.json", "r", encoding="utf-8") as f:
    places = json.load(f)

# %%
place_api_key = "AIzaSyC8_ZI60qd7si1LPT5EvpICyeCYaxxFgTI"
url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

def get_places(query):
    PARAMS = {
        "key": place_api_key,
        "query": query,
        "language": "ru",
        "location": "53.900615,27.559027",
        "radius": "10"
    }

    while True:
        r = requests.get(url = url, params = PARAMS)
        data = r.json()
        results = data['results']
        for r in results:
            yield r
            #print(r['name'])
            #print(r['types'])
            #print(r['formatted_address'])
            #print()

        if 'next_page_token' in data:
            PARAMS['pagetoken'] = data['next_page_token']
        else:
            break

# %%
new_places = {}
for address, place in places.items():
    google_places = get_places(place)
    for google_place in google_places:
        name = google_place['name']
        formatted_address = google_place['formatted_address'].split(",")
        if len(formatted_address) <= 2:
            continue
        if "минск" not in  formatted_address[-2].lower():
            continue
        formatted_address = ",".join([a for a in formatted_address[:-2] if not a.isdigit()])
        if not formatted_address:
            continue
        if formatted_address not in new_places:
            new_places[formatted_address] = []
        print(formatted_address, name)
        new_places[formatted_address].append(name)
# Out:
# проспект Независимости 50 Белорусская государственная филармония
# ул. Интернациональная 30 Белорусская государственная академия музыки
# ул. Советская 18 Белорусский государственный педагогический университет имени Максима Танка
# Верхний город Верхний город
# ул. Кульман 40 Друзья
# улица Октябрьская 5 Концертный зал Минск
# улица Толбухина д.4 KILLFISH BAR
# проспект Дзержинского д.104 KILLFISH Bar
# ул. Куйбышева 45 Standup comedy hall
# ул. Красноармейская 3 Центральный дом офицеров
# пр-т. Победителей 65 Прайм холл
# ул. Притыцкого 62 RE:PUBLIC
# ул. Долгобродская 24 Дворец культуры Минского тракторного завода
# Партизанский просп. 6А Клуб Брюгге
# Парк им Горького, улица Фрунзе 2 Минский планетарий
# улица Московская 18а Молодежный Театр Эстрады
# ул. Азгура 8 Мемориальный музей-мастерская З.И. Азгура
# пл. Парижской Коммуны 1 Большой театр Беларуси
# ул. Мележа 5/1 CUBA BAR
# проспект Независимости 37 Выставочный зал LIBRA
# пер. Калинина 11 Автоцентр Либра-2000
# ...

# %%
with open("..//data//places.json", "w", encoding="utf-8") as f:
    json.dump(places, f, indent=4, ensure_ascii=False)

# %%
types = [
    "amusement_park",
    "aquarium",
    "art_gallery",
    "bakery",
    "bar",
    "book_store",
    "bowling_alley",
    "cafe",
    "church",
    "embassy",
    "gym",
    "library",
    "movie_theater",
    "museum",
    "night_club",
    "park",
    "restaurant",
    "shopping_mall",
    "stadium",
    "synagogue",
    "university",
    "zoo",
    "food",
    "town_square"]
